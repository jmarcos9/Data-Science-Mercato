# %%
import pandas as pd
base = pd.read_excel('base_faturamento.xlsx')
produtos = pd.read_excel('base_produtos.xlsx')
clientes = pd.read_excel("base _clientes.xlsx")

# %%
base.head(2)
# Out:
#    COD  Cliente Estado Dest.  COD Produto     Produto  \
# 0   42      NaN           SC          NaN  1001000003
# 1   42      NaN           SC          NaN  1001000004
#
#                        Dsc.Produto Unidade  Quantidade  Vlr.Unitario  \
# 0   SAL DEFUMADO C/MOEDOR KOOK 90G      UN       120.0         10.11
# 1  SAL COM LIMÃO C/MOEDOR KOOK 90G      UN       120.0         10.11
#
#    Vlr.Total  ...  Base Imp. 6  Valor Imp. 5  Valor Imp. 6  Aliq. Imp. 5  \
# 0     1213.2  ...       1213.2         36.40          7.88             3
# 1     1213.2  ...       1213.2         36.39          7.89             3
#
#    Aliq. Imp. 6  Grupo.1  Vlr.Bruto  Aliq. CSLL  Aliq. Pis Aliq. Cofins
# 0          0.65     1001     1213.2           1       0.65            3
# 1          0.65     1001     1213.2           1       0.65            3
#
# [2 rows x 45 columns]

# %%
base = base[["COD", "Estado Dest.","Produto",'Dsc.Produto', "Quantidade",'Vlr.Unitario', "Vlr.Total"  ]]

# %%
produtos.head()
# Out:
#        Codigo CATEGORIA FAMILIA                          Descricao Tipo  \
# 0  1001000001       SAL  MOEDOR  SAL DO HIMALAIA C/MOEDOR KOOK 90G   PA
# 1  1001000002       SAL  MOEDOR      SAL MARINHO C/MOEDOR KOOK 90G   PA
# 2  1001000003       SAL  MOEDOR     SAL DEFUMADO C/MOEDOR KOOK 90G   PA
# 3  1001000004       SAL  MOEDOR    SAL COM LIMÃO C/MOEDOR KOOK 90G   PA
# 4  1001000005       SAL  MOEDOR     SAL COM ALHO C/MOEDOR KOOK 90G   PA
#
#   Unidade  Armazem Pad. Pos.IPI/NCM  Cód. Venda Seg.Un.Medi.  ...  \
# 0      UN           1.0  2501.00.11         6.0           CX  ...
# 1      UN           1.0  2501.00.11         4.0           CX  ...
# 2      UN           1.0  2501.00.90         5.0           CX  ...
# 3      UN           1.0  2501.00.90        25.0           CX  ...
# 4      UN           1.0  2501.00.90        31.0           CX  ...
#
#    Preco Venda  Ponto Pedido  Ult. Preco  Peso Liquido  PESO BRUTO  \
# ...

# %%
clientes
# Out:
#     Codigo                                            Nome  \
# 0        1                       GALPAO GOURMET LTDA - EPP
# 1        3                         HORTIGIL HORTIFRUTI S/A
# 2        4          RIO QUALITY COMERCIO DE ALIMENTOS LTDA
# 3        5        MUNDO MAIS NATURAL DISTRIBUIDORA DE PROD
# 4        6        MUNDO NATURAL DISTRIBUIDORA DE ALIMENTOS
# ..     ...                                             ...
# 965    981            LOPES SUPERMERCADOS LTDA - CATANDUVA
# 966    982                         MERCANTIL NOVA ERA LTDA
# 967    983  CHEF MEDITERRANEO IMPORTACAO EXPORTACAO EIRELI
# 968    984            VIMCART INDUSTRIA E COMERCIO LTDA ME
# 969    985                HOTELARIA ACCORINVEST BRASIL S.A
#
#                                           RCA         CANAL    REGIÃO  \
# 0    MCG REPRESENTACOES E ASSESSORIA EMPRESAR          REDE   SUDESTE
# 1    MCG REPRESENTACOES E ASSESSORIA EMPRESAR          REDE   SUDESTE
# ...

# %%
clientes
# Out:
#     Codigo                                            Nome  \
# 0        1                       GALPAO GOURMET LTDA - EPP
# 1        3                         HORTIGIL HORTIFRUTI S/A
# 2        4          RIO QUALITY COMERCIO DE ALIMENTOS LTDA
# 3        5        MUNDO MAIS NATURAL DISTRIBUIDORA DE PROD
# 4        6        MUNDO NATURAL DISTRIBUIDORA DE ALIMENTOS
# ..     ...                                             ...
# 965    981            LOPES SUPERMERCADOS LTDA - CATANDUVA
# 966    982                         MERCANTIL NOVA ERA LTDA
# 967    983  CHEF MEDITERRANEO IMPORTACAO EXPORTACAO EIRELI
# 968    984            VIMCART INDUSTRIA E COMERCIO LTDA ME
# 969    985                HOTELARIA ACCORINVEST BRASIL S.A
#
#                                           RCA         CANAL    REGIÃO  \
# 0    MCG REPRESENTACOES E ASSESSORIA EMPRESAR          REDE   SUDESTE
# 1    MCG REPRESENTACOES E ASSESSORIA EMPRESAR          REDE   SUDESTE
# ...
